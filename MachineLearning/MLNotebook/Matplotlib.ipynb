# %% [markdown]
# # 1. Basic

# %%
import matplotlib.pyplot as plt
import numpy as np

# x is 50 points from -1 to 1
x = np.linspace(-1, 1, 50)
y = 2*x + 1 
y2 = x**2
plt.plot(x, y2)
plt.show()

# %% [markdown]
# ## 1.1 Figure
#     Different pics can stay in different figures.

# %%
xn = np.linspace(-3, 3, 50)

# figure(num=3, figsize=(8,5))
plt.figure()
plt.plot(xn, y)

plt.figure()
plt.plot(xn, y)
plt.plot(xn, y2, color='red', linewidth=1.0, linestyle='--')

# %% [markdown]
# ## 1.2 Aixs
#     change tick of axis

# %%
plt.plot(xn, y)
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('I am x')
plt.ylabel('I am y')

new_ticks = np.linspace(-1, 2, 5)
print(new_ticks)
plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3], [r"$really\ bad$", r"$bad$", r"$normal$", r"$good$", r"$really\ good$"])
# Out:
# [-1.   -0.25  0.5   1.25  2.  ]
# ([<matplotlib.axis.YTick at 0x7f10cfe85518>,
# ...
#  [Text(0, -2.0, '$really\\ bad$'),
#   Text(0, -1.8, '$bad$'),
#   Text(0, -1.0, '$normal$'),
#   Text(0, 1.22, '$good$'),
#   Text(0, 3.0, '$really\\ good$')])

# %% [markdown]
# ## 1.3 gca = get current axis

# %%
plt.plot(xn, y)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.splines['bottom'].set_position
